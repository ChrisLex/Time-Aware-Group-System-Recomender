# %%
# Librerías de procesamiento y transformación de datos
import pandas as pd
import csv
import numpy as np
from math import pow, sqrt

# Otras Librerías 
import os
import random
import sys
from datetime import date
from datetime import datetime
# Out:
# C:\Users\ChrisLex\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\ChrisLex\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
# C:\Users\ChrisLex\anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size2_MPS.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation is: \n")
print(dataframe1)
bxp2t0 = df.boxplot(column =['RatingsGroups'], grid = False)


plt.title("MPS Size2 T1")
plt.suptitle("")
plt.xlabel("Size2")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation is:
#
# 0.38771065778353836

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size2_MPS_4.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation is: \n")
print(dataframe1)
bxp = df.boxplot(column =['RatingsGroups'], grid = False)


plt.title("MPS Size2 T2")
plt.suptitle("")
plt.xlabel("Size2")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation is:
#
# 0.2822393603813693

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size2_MPS_5.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation is: \n")
print(dataframe1)
bxp = df.boxplot(column =['RatingsGroups'], grid = False)


plt.title("MPS Size2 T3")
plt.suptitle("")
plt.xlabel("Size2")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation is:
#
# 0.23471269677099854

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size3_MPS.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation is: \n")
print(dataframe1)
bxp = df.boxplot(column =['RatingsGroups'], grid = False)


plt.title("MPS Size3 T1")
plt.suptitle("")
plt.xlabel("Size2")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation is:
#
# 0.36206310375083905

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size3_MPS_4.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation is: \n")
print(dataframe1)
bxp = df.boxplot(column =['RatingsGroups'], grid = False)


plt.title("MPS Size3 T2")
plt.suptitle("")
plt.xlabel("Size2")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation is:
#
# 0.255839830802744

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size3_MPS_5.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation is: \n")
print(dataframe1)
bxp = df.boxplot(column =['RatingsGroups'], grid = False)


plt.title("MPS Size3 T3")
plt.suptitle("")
plt.xlabel("Size2")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation is:
#
# 0.21178729213948289

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size4_MPS.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation is: \n")
print(dataframe1)
bxp = df.boxplot(column =['RatingsGroups'], grid = False)


plt.title("MPS Size4 T1")
plt.suptitle("")
plt.xlabel("Size2")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation is:
#
# 0.35260777799552656

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size4_MPS_4.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation is: \n")
print(dataframe1)
bxp = df.boxplot(column =['RatingsGroups'], grid = False)


plt.title("MPS Size4 T2")
plt.suptitle("")
plt.xlabel("Size2")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation is:
#
# 0.24736776874635077

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size4_MPS_5.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation is: \n")
print(dataframe1)
bxp = df.boxplot(column =['RatingsGroups'], grid = False)


plt.title("MPS Size4 T3")
plt.suptitle("")
plt.xlabel("Size2")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation is:
#
# 0.20759609450721866

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size5_MPS.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation is: \n")
print(dataframe1)
bxp = df.boxplot(column =['RatingsGroups'], grid = False)


plt.title("MPS Size5 T1")
plt.suptitle("")
plt.xlabel("Size2")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation is:
#
# 0.3469270467735154

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size5_MPS_4.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation is: \n")
print(dataframe1)
bxp = df.boxplot(column =['RatingsGroups'], grid = False)


plt.title("MPS Size5 T2")
plt.suptitle("")
plt.xlabel("Size2")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation is:
#
# 0.2412416917857878

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size5_MPS_5.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation is: \n")
print(dataframe1)
bxp = df.boxplot(column =['RatingsGroups'], grid = False)


plt.title("MPS Size5 T3")
plt.suptitle("")
plt.xlabel("Size2")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation is:
#
# 0.20943115105992877

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size6_MPS.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation is: \n")
print(dataframe1)
bxp = df.boxplot(column =['RatingsGroups'], grid = False)


plt.title("MPS Size6 T1")
plt.suptitle("")
plt.xlabel("Size2")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation is:
#
# 0.3426632150680348

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size6_MPS_4.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation is: \n")
print(dataframe1)
bxp = df.boxplot(column =['RatingsGroups'], grid = False)


plt.title("MPS Size6 T2")
plt.suptitle("")
plt.xlabel("Size2")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation is:
#
# 0.23904676070764103

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size6_MPS_5.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation is: \n")
print(dataframe1)
bxp = df.boxplot(column =['RatingsGroups'], grid = False)


plt.title("MPS Size6 T3")
plt.suptitle("")
plt.xlabel("Size2")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation is:
#
# 0.20671350356403786

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size7_MPS.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation is: \n")
print(dataframe1)
bxp = df.boxplot(column =['RatingsGroups'], grid = False)


plt.title("MPS Size7 T1")
plt.suptitle("")
plt.xlabel("Size2")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation is:
#
# 0.33677830307214685

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size7_MPS_4.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation is: \n")
print(dataframe1)
bxp = df.boxplot(column =['RatingsGroups'], grid = False)


plt.title("MPS Size7 T2")
plt.suptitle("")
plt.xlabel("Size2")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation is:
#
# 0.233512194235224

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size7_MPS_5.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation is: \n")
print(dataframe1)
bxp = df.boxplot(column =['RatingsGroups'], grid = False)


plt.title("MPS Size7 T3")
plt.suptitle("")
plt.xlabel("Size2")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation is:
#
# 0.21355317606296378

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size8_MPS.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation is: \n")
print(dataframe1)
bxp8t0 = df.boxplot(column =['RatingsGroups'], grid = False)


plt.title("MPS Size8 T1")
plt.suptitle("")
plt.xlabel("Size2")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation is:
#
# 0.3399835550740606

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size8_MPS_4.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation is: \n")
print(dataframe1)
bxp8t1 = df.boxplot(column =['RatingsGroups'], grid = False)


plt.title("MPS Size8 T2")
plt.suptitle("")
plt.xlabel("Size2")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation is:
#
# 0.23369865287107788

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size8_MPS_5.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation is: \n")
print(dataframe1)
bxp8t2 = df.boxplot(column =['RatingsGroups'], grid = False)

plt.title("MPS Size8 T3")
plt.suptitle("")
plt.xlabel("Size2")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation is:
#
# 0.20349041635909804

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size2_MPS.csv")
df8 = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size8_MPS.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation (size 2) is: \n")
print(dataframe1)
dataframe8 = df8['RatingsGroups'].std(axis= 0)
print("The Standard Deviation (size 8) is: \n")
print(dataframe8)

df['RatingsGroups8'] = df8['RatingsGroups']

df.boxplot(column =['RatingsGroups','RatingsGroups8'], grid = False)


plt.title("MPS T1")
plt.suptitle("")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation (size 2) is:
#
# 0.38771065778353836
# The Standard Deviation (size 8) is:
#
# 0.3399835550740606

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size2_MPS_4.csv")
df8 = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size8_MPS_4.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation (size 2) is: \n")
print(dataframe1)
dataframe8 = df8['RatingsGroups'].std(axis= 0)
print("The Standard Deviation (size 8) is: \n")
print(dataframe8)

df['RatingsGroups8'] = df8['RatingsGroups']

df.boxplot(column =['RatingsGroups','RatingsGroups8'], grid = False)


plt.title("MPS T2")
plt.suptitle("")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation (size 2) is:
#
# 0.2822393603813693
# The Standard Deviation (size 8) is:
#
# 0.23369865287107788

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size2_MPS_5.csv")
df8 = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size8_MPS_5.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation (size 2) is: \n")
print(dataframe1)
dataframe8 = df8['RatingsGroups'].std(axis= 0)
print("The Standard Deviation (size 8) is: \n")
print(dataframe8)

df['RatingsGroups8'] = df8['RatingsGroups']

df.boxplot(column =['RatingsGroups','RatingsGroups8'], grid = False)


plt.title("MPS T3")
plt.suptitle("")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation (size 2) is:
#
# 0.23471269677099854
# The Standard Deviation (size 8) is:
#
# 0.20349041635909804

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size2_LMS.csv")
df8 = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size8_LMS.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation (size 2) is: \n")
print(dataframe1)
dataframe8 = df8['RatingsGroups'].std(axis= 0)
print("The Standard Deviation (size 8) is: \n")
print(dataframe8)

df['RatingsGroups8'] = df8['RatingsGroups']

df.boxplot(column =['RatingsGroups','RatingsGroups8'], grid = False)


plt.title("LMS T1")
plt.suptitle("")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation (size 2) is:
#
# 0.4293340682295368
# The Standard Deviation (size 8) is:
#
# 0.41821579503226536

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size2_LMS_4.csv")
df8 = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size8_LMS_4.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation (size 2) is: \n")
print(dataframe1)
dataframe8 = df8['RatingsGroups'].std(axis= 0)
print("The Standard Deviation (size 8) is: \n")
print(dataframe8)

df['RatingsGroups8'] = df8['RatingsGroups']

df.boxplot(column =['RatingsGroups','RatingsGroups8'], grid = False)


plt.title("LMS T2")
plt.suptitle("")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation (size 2) is:
#
# 0.3276458287675433
# The Standard Deviation (size 8) is:
#
# 0.3354852858388101

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
df = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size2_LMS_5.csv")
df8 = pd.read_csv("Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size8_LMS_5.csv")
dataframe1 = df['RatingsGroups'].std(axis= 0)
print("The Standard Deviation (size 2) is: \n")
print(dataframe1)
dataframe8 = df8['RatingsGroups'].std(axis= 0)
print("The Standard Deviation (size 8) is: \n")
print(dataframe8)

df['RatingsGroups8'] = df8['RatingsGroups']

df.boxplot(column =['RatingsGroups','RatingsGroups8'], grid = False)


plt.title("LMS T3")
plt.suptitle("")
plt.ylabel("RatingsGroups")
plt.show()
# Out:
# The Standard Deviation (size 2) is:
#
# 0.2679290935404088
# The Standard Deviation (size 8) is:
#
# 0.3364238772774801
