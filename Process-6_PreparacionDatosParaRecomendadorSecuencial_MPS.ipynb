# %%
# Librerías de procesamiento y transformación de datos
import pandas as pd
import csv
import numpy as np
from math import pow, sqrt

# Otras Librerías 
import os
import random
import sys
from datetime import date
from datetime import datetime
# Out:
# C:\Users\ChrisLex\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\ChrisLex\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
# C:\Users\ChrisLex\anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
size2_MPS1 = pd.read_csv('Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size2_MPS.csv')
size2_MPS2 = pd.read_csv('Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size2_MPS_4.csv')
size2_MPS3 = pd.read_csv('Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size2_MPS_5.csv')

# %%
size5_MPS1 = pd.read_csv('Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size5_MPS.csv')
size5_MPS2 = pd.read_csv('Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size5_MPS_4.csv')
size5_MPS3 = pd.read_csv('Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size5_MPS_5.csv')

# %%
size8_MPS1 = pd.read_csv('Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size8_MPS.csv')
size8_MPS2 = pd.read_csv('Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size8_MPS_4.csv')
size8_MPS3 = pd.read_csv('Tesis/item-KNN/1.Baseline/agregaciones/group_movies_size8_MPS_5.csv')

# %%
import datetime
ts = datetime.datetime.now().timestamp()
size2_MPS1['session_id'] = size2_MPS1.index
size2_MPS1['ts'] = ts

ts = datetime.datetime.now().timestamp()
size2_MPS2['session_id'] = size2_MPS2.index
size2_MPS2['ts'] = ts+1

ts = datetime.datetime.now().timestamp()
size2_MPS3['session_id'] = size2_MPS3.index
size2_MPS3['ts'] = ts+2

# %%
import datetime
ts = datetime.datetime.now().timestamp()
size5_MPS1['session_id'] = size5_MPS1.index
size5_MPS1['ts'] = ts

ts = datetime.datetime.now().timestamp()
size5_MPS2['session_id'] = size5_MPS2.index
size5_MPS2['ts'] = ts+1

ts = datetime.datetime.now().timestamp()
size5_MPS3['session_id'] = size5_MPS3.index
size5_MPS3['ts'] = ts+2

# %%
import datetime
ts = datetime.datetime.now().timestamp()
size8_MPS1['session_id'] = size8_MPS1.index
size8_MPS1['ts'] = ts

ts = datetime.datetime.now().timestamp()
size8_MPS2['session_id'] = size8_MPS2.index
size8_MPS2['ts'] = ts+1

ts = datetime.datetime.now().timestamp()
size8_MPS3['session_id'] = size8_MPS3.index
size8_MPS3['ts'] = ts+2

# %%
UniqueGenre = pd.read_csv('moviesUniqueGenre.csv')
print(UniqueGenre.genres.unique())
# Out:
# ['Adventure' 'Comedy' 'Action' 'Drama' 'Crime' 'Children' 'Mystery'
#  'Documentary' 'Animation' 'Thriller' 'Horror' 'Fantasy' 'Western'
#  'Film-Noir' 'Romance' 'War' 'Sci-Fi' 'Musical' 'IMAX'
#  '(no genres listed)']

# %%
#newdf = new3.loc[(new3.genres == "Mystery")]     #27030  ******
#newdf = new3.loc[(new3.genres == "Adventure")]   #349005
#newdf = new3.loc[(new3.genres == "Comedy")]      #1530375 
#newdf = new3.loc[(new3.genres == "Action")]      #960360  
#newdf = new3.loc[(new3.genres == "Drama")]       #1505730  
#newdf = new3.loc[(new3.genres == "Crime")]       #408630   
#newdf = new3.loc[(new3.genres == "Children")]    #102555  
#newdf = new3.loc[(new3.genres == "Documentary")] #102555  
#newdf = new3.loc[(new3.genres == "Animation")]   #104145    
#newdf = new3.loc[(new3.genres == "Thriller")]    #43725  ********* 
#newdf = new3.loc[(new3.genres == "Horror")]      #288585    
#newdf = new3.loc[(new3.genres == "Fantasy")]     #29415  ******* 
#newdf = new3.loc[(new3.genres == "Western")]     #33390  ********
#newdf = new3.loc[(new3.genres == "Film-Noir")]   #14310  **     
#newdf = new3.loc[(new3.genres == "Romance")]     #23055  *****   
#newdf = new3.loc[(new3.genres == "War")]         #4770   *
#newdf = new3.loc[(new3.genres == "Sci-Fi")]      #19080  ****   
#newdf = new3.loc[(new3.genres == "Musical")]      #15900  ***

# %%
#SIZE2

# %%
new1 = pd.merge(size2_MPS1, UniqueGenre, on='mmovieId', how='left')
new1.drop(new1.columns[5], axis=1, inplace=True)
new1.drop(new1.columns[3], axis=1, inplace=True)

new2 = pd.merge(size2_MPS2, UniqueGenre, on='mmovieId', how='left')
new2.drop(new2.columns[5], axis=1, inplace=True)
new2.drop(new2.columns[3], axis=1, inplace=True)

new3 = pd.merge(size2_MPS3, UniqueGenre, on='mmovieId', how='left')
new3.drop(new3.columns[5], axis=1, inplace=True)
new3.drop(new3.columns[3], axis=1, inplace=True)

# %%
#GENERO War
new1_1 = new1
new2_1 = new2
new3_1 = new3

#FILTRO DE GENERO Sci-Fi
#new1_1 = new1_1.loc[(new1_1.genres == "War")]
#new2_1 = new2_1.loc[(new2_1.genres == "War")]
#new3_1 = new3_1.loc[(new3_1.genres == "War")]
#new1_1 = new1_1.loc[(new1_1.genres == "Sci-Fi")]
#new2_1 = new2_1.loc[(new2_1.genres == "Sci-Fi")]
#new3_1 = new3_1.loc[(new3_1.genres == "Sci-Fi")]
new1_1 = new1_1.loc[(new1_1.genres == "Thriller")]
new2_1 = new2_1.loc[(new2_1.genres == "Thriller")]
new3_1 = new3_1.loc[(new3_1.genres == "Thriller")]

#ELIMINACION DE COLUMNA session_id 
new1_1.drop(new1_1.columns[4], axis=1, inplace=True)
new2_1.drop(new2_1.columns[4], axis=1, inplace=True)
new3_1.drop(new3_1.columns[4], axis=1, inplace=True)

#rESETEAMOS EL INDICE
new1_1.reset_index(inplace=True, drop=False)
new2_1.reset_index(inplace=True, drop=False)
new3_1.reset_index(inplace=True, drop=False)

#CARGAMOS EL NUEVO INDICE A LA COLUMNA SESSION_ID
new1_1['session_id'] = new1_1.index
new2_1['session_id'] = new2_1.index
new3_1['session_id'] = new3_1.index

#ELIMINACION DE COLUMNA INDEX 
new1_1.drop(new1_1.columns[0], axis=1, inplace=True)
new2_1.drop(new2_1.columns[0], axis=1, inplace=True)
new3_1.drop(new3_1.columns[0], axis=1, inplace=True)

#TRANSFORMACION DE DECIMAL A ENTERO
new1_1['RatingsGroups'] = new1_1['RatingsGroups']*100
new2_1['RatingsGroups'] = new2_1['RatingsGroups']*100
new3_1['RatingsGroups'] = new3_1['RatingsGroups']*100

#Elimino valores NAN
new1_1.dropna(subset = ["RatingsGroups"], inplace=True)
new2_1.dropna(subset = ["RatingsGroups"], inplace=True)
new3_1.dropna(subset = ["RatingsGroups"], inplace=True)

new1_1['RatingsGroups'] = new1_1['RatingsGroups'].astype(int,errors='ignore')
new2_1['RatingsGroups'] = new2_1['RatingsGroups'].astype(int,errors='ignore')
new3_1['RatingsGroups'] = new3_1['RatingsGroups'].astype(int,errors='ignore')

new1_1['mmovieId'] = new1_1['mmovieId'].astype(int,errors='ignore')
new2_1['mmovieId'] = new2_1['mmovieId'].astype(int,errors='ignore')
new3_1['mmovieId'] = new3_1['mmovieId'].astype(int,errors='ignore')
print(new1_1)
print(new2_1)
print(new3_1)
import os
if(os.path.exists('MPS1Size2_war0.csv')):
    os.remove("MPS1Size2_war0.csv")
if(os.path.exists('MPS1Size2_war.csv')):
    os.remove("MPS1Size2_war.csv")

import csv
with open('MPS1Size2_war0.csv', 'w', newline='') as file:
    writer = csv.writer(file)
file.close()
with open('MPS1Size2_war.csv', 'w', newline='') as file:
    writer = csv.writer(file)
file.close()

with open('MPS1Size2_war0.csv', 'a') as f:
    new1_1.to_csv(f,index=False)
    new2_1.to_csv(f,header=False,index=False)
    new3_1.to_csv(f,header=False,index=False)
f.close()

with open('MPS1Size2_war0.csv') as input, open('MPS1Size2_war.csv', 'w', newline='') as output:
     writer = csv.writer(output)
     for row in csv.reader(input):
         if any(field.strip() for field in row):
             writer.writerow(row)

df003 = pd.read_csv('MPS1Size2_war.csv')
print(df003)
# Out:
# C:\Users\ChrisLex\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# <ipython-input-12-f2d0e9936a15>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1['session_id'] = new1_1.index
# <ipython-input-12-f2d0e9936a15>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1['session_id'] = new2_1.index
# <ipython-input-12-f2d0e9936a15>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1['session_id'] = new3_1.index
# <ipython-input-12-f2d0e9936a15>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1['RatingsGroups'] = new1_1['RatingsGroups']*100
# <ipython-input-12-f2d0e9936a15>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1['RatingsGroups'] = new2_1['RatingsGroups']*100
# <ipython-input-12-f2d0e9936a15>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1['RatingsGroups'] = new3_1['RatingsGroups']*100
# <ipython-input-12-f2d0e9936a15>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1.dropna(subset = ["RatingsGroups"], inplace=True)
# <ipython-input-12-f2d0e9936a15>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1.dropna(subset = ["RatingsGroups"], inplace=True)
# <ipython-input-12-f2d0e9936a15>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1.dropna(subset = ["RatingsGroups"], inplace=True)
# <ipython-input-12-f2d0e9936a15>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1['RatingsGroups'] = new1_1['RatingsGroups'].astype(int)
# <ipython-input-12-f2d0e9936a15>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1['RatingsGroups'] = new2_1['RatingsGroups'].astype(int)
# <ipython-input-12-f2d0e9936a15>:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1['RatingsGroups'] = new3_1['RatingsGroups'].astype(int)
# <ipython-input-12-f2d0e9936a15>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1['mmovieId'] = new1_1['mmovieId'].astype(int)
# <ipython-input-12-f2d0e9936a15>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1['mmovieId'] = new2_1['mmovieId'].astype(int)
# <ipython-input-12-f2d0e9936a15>:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1['mmovieId'] = new3_1['mmovieId'].astype(int)
#        GroupID  mmovieId  RatingsGroups            ts  session_id
# 0            0       132            354  1.650398e+09           0
# 1            1       132            318  1.650398e+09           1
# 2            2       132            294  1.650398e+09           2
# 3            3       132            325  1.650398e+09           3
# 4            4       132            358  1.650398e+09           4
# ...        ...       ...            ...           ...         ...
# 43555      787     71011            405  1.650398e+09       43555
# 43556      788     71011            303  1.650398e+09       43556
# 43557      789     71011            381  1.650398e+09       43557
# 43558      790     71011            352  1.650398e+09       43558
# 43559      791     71011            320  1.650398e+09       43559
#
# [43140 rows x 5 columns]
#        GroupID  mmovieId  RatingsGroups            ts  session_id
# 0            0       132            362  1.650398e+09           0
# 1            1       132            343  1.650398e+09           1
# 2            2       132            304  1.650398e+09           2
# 3            3       132            356  1.650398e+09           3
# 4            4       132            364  1.650398e+09           4
# ...        ...       ...            ...           ...         ...
# 43555      787     71011            372  1.650398e+09       43555
# 43556      788     71011            355  1.650398e+09       43556
# 43557      789     71011            368  1.650398e+09       43557
# 43558      790     71011            359  1.650398e+09       43558
# 43559      791     71011            343  1.650398e+09       43559
#
# [43140 rows x 5 columns]
#        GroupID  mmovieId  RatingsGroups            ts  session_id
# 0            0       132            346  1.650398e+09           0
# 1            1       132            330  1.650398e+09           1
# 2            2       132            316  1.650398e+09           2
# 3            3       132            331  1.650398e+09           3
# 4            4       132            334  1.650398e+09           4
# ...        ...       ...            ...           ...         ...
# 43555      787     71011            365  1.650398e+09       43555
# 43556      788     71011            321  1.650398e+09       43556
# 43557      789     71011            351  1.650398e+09       43557
# 43558      790     71011            356  1.650398e+09       43558
# 43559      791     71011            353  1.650398e+09       43559
#
# [43140 rows x 5 columns]
#         GroupID  mmovieId  RatingsGroups            ts  session_id
# 0             0       132            354  1.650398e+09           0
# 1             1       132            318  1.650398e+09           1
# 2             2       132            294  1.650398e+09           2
# 3             3       132            325  1.650398e+09           3
# 4             4       132            358  1.650398e+09           4
# ...         ...       ...            ...           ...         ...
# 129415      787     71011            365  1.650398e+09       43555
# 129416      788     71011            321  1.650398e+09       43556
# 129417      789     71011            351  1.650398e+09       43557
# 129418      790     71011            356  1.650398e+09       43558
# 129419      791     71011            353  1.650398e+09       43559
#
# [129420 rows x 5 columns]

# %%
#GENERO Sci-Fi
new1_1 = new1
new2_1 = new2
new3_1 = new3

#FILTRO DE GENERO Sci-Fi
new1_1 = new1_1.loc[(new1_1.genres == "Sci-Fi")]
new2_1 = new2_1.loc[(new2_1.genres == "Sci-Fi")]
new3_1 = new3_1.loc[(new3_1.genres == "Sci-Fi")]

#ELIMINACION DE COLUMNA session_id 
new1_1.drop(new1_1.columns[4], axis=1, inplace=True)
new2_1.drop(new2_1.columns[4], axis=1, inplace=True)
new3_1.drop(new3_1.columns[4], axis=1, inplace=True)

#rESETEAMOS EL INDICE
new1_1.reset_index(inplace=True, drop=False)
new2_1.reset_index(inplace=True, drop=False)
new3_1.reset_index(inplace=True, drop=False)

#CARGAMOS EL NUEVO INDICE A LA COLUMNA SESSION_ID
new1_1['session_id'] = new1_1.index
new2_1['session_id'] = new2_1.index
new3_1['session_id'] = new3_1.index

#ELIMINACION DE COLUMNA INDEX 
new1_1.drop(new1_1.columns[0], axis=1, inplace=True)
new2_1.drop(new2_1.columns[0], axis=1, inplace=True)
new3_1.drop(new3_1.columns[0], axis=1, inplace=True)

#TRANSFORMACION DE DECIMAL A ENTERO
new1_1['RatingsGroups'] = new1_1['RatingsGroups']*100
new2_1['RatingsGroups'] = new2_1['RatingsGroups']*100
new3_1['RatingsGroups'] = new3_1['RatingsGroups']*100

#Elimino valores NAN
new1_1.dropna(subset = ["RatingsGroups"], inplace=True)
new2_1.dropna(subset = ["RatingsGroups"], inplace=True)
new3_1.dropna(subset = ["RatingsGroups"], inplace=True)

new1_1['RatingsGroups'] = new1_1['RatingsGroups'].astype(int,errors='ignore')
new2_1['RatingsGroups'] = new2_1['RatingsGroups'].astype(int,errors='ignore')
new3_1['RatingsGroups'] = new3_1['RatingsGroups'].astype(int,errors='ignore')

new1_1['mmovieId'] = new1_1['mmovieId'].astype(int,errors='ignore')
new2_1['mmovieId'] = new2_1['mmovieId'].astype(int,errors='ignore')
new3_1['mmovieId'] = new3_1['mmovieId'].astype(int,errors='ignore')

import os

if(os.path.exists('MPS1Size2_sf0.csv')):
    os.remove("MPS1Size2_sf0.csv")
if(os.path.exists('MPS1Size2_sf.csv')):
    os.remove("MPS1Size2_sf.csv")

import csv
with open('MPS1Size2_sf0.csv', 'w', newline='') as file:
    writer = csv.writer(file)
file.close()
with open('MPS1Size2_sf.csv', 'w', newline='') as file:
    writer = csv.writer(file)
file.close()

with open('MPS1Size2_sf0.csv', 'a') as f:
    new1_1.to_csv(f,index=False)
    new2_1.to_csv(f,header=False,index=False)
    new3_1.to_csv(f,header=False,index=False)
f.close()

with open('MPS1Size2_sf0.csv') as input, open('MPS1Size2_sf.csv', 'w', newline='') as output:
     writer = csv.writer(output)
     for row in csv.reader(input):
         if any(field.strip() for field in row):
             writer.writerow(row)

df003 = pd.read_csv('MPS1Size2_sf.csv')
print(df003)
# Out:
# C:\Users\ChrisLex\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# <ipython-input-13-26808abf28e2>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1['session_id'] = new1_1.index
# <ipython-input-13-26808abf28e2>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1['session_id'] = new2_1.index
# <ipython-input-13-26808abf28e2>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1['session_id'] = new3_1.index
# <ipython-input-13-26808abf28e2>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1['RatingsGroups'] = new1_1['RatingsGroups']*100
# <ipython-input-13-26808abf28e2>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1['RatingsGroups'] = new2_1['RatingsGroups']*100
# <ipython-input-13-26808abf28e2>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1['RatingsGroups'] = new3_1['RatingsGroups']*100
# <ipython-input-13-26808abf28e2>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1.dropna(subset = ["RatingsGroups"], inplace=True)
# <ipython-input-13-26808abf28e2>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1.dropna(subset = ["RatingsGroups"], inplace=True)
# <ipython-input-13-26808abf28e2>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1.dropna(subset = ["RatingsGroups"], inplace=True)
# <ipython-input-13-26808abf28e2>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1['RatingsGroups'] = new1_1['RatingsGroups'].astype(int)
# <ipython-input-13-26808abf28e2>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1['RatingsGroups'] = new2_1['RatingsGroups'].astype(int)
# <ipython-input-13-26808abf28e2>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1['RatingsGroups'] = new3_1['RatingsGroups'].astype(int)
# <ipython-input-13-26808abf28e2>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1['mmovieId'] = new1_1['mmovieId'].astype(int)
# <ipython-input-13-26808abf28e2>:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1['mmovieId'] = new2_1['mmovieId'].astype(int)
# <ipython-input-13-26808abf28e2>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1['mmovieId'] = new3_1['mmovieId'].astype(int)
#        GroupID  mmovieId  RatingsGroups            ts  session_id
# 0            0       880            270  1.650398e+09           0
# 1            1       880            235  1.650398e+09           1
# 2            2       880            227  1.650398e+09           2
# 3            3       880            258  1.650398e+09           3
# 4            4       880            271  1.650398e+09           4
# ...        ...       ...            ...           ...         ...
# 56764      787     72630            362  1.650398e+09       19003
# 56765      788     72630            322  1.650398e+09       19004
# 56766      789     72630            339  1.650398e+09       19005
# 56767      790     72630            360  1.650398e+09       19006
# 56768      791     72630            364  1.650398e+09       19007
#
# [56769 rows x 5 columns]

# %%
#SIZE 5

# %%
new1 = pd.merge(size5_MPS1, UniqueGenre, on='mmovieId', how='left')
new1.drop(new1.columns[5], axis=1, inplace=True)
new1.drop(new1.columns[3], axis=1, inplace=True)

new2 = pd.merge(size5_MPS2, UniqueGenre, on='mmovieId', how='left')
new2.drop(new2.columns[5], axis=1, inplace=True)
new2.drop(new2.columns[3], axis=1, inplace=True)

new3 = pd.merge(size5_MPS3, UniqueGenre, on='mmovieId', how='left')
new3.drop(new3.columns[5], axis=1, inplace=True)
new3.drop(new3.columns[3], axis=1, inplace=True)

# %%
#GENERO War
new1_1 = new1
new2_1 = new2
new3_1 = new3

#FILTRO DE GENERO Sci-Fi
#new1_1 = new1_1.loc[(new1_1.genres == "War")]
#new2_1 = new2_1.loc[(new2_1.genres == "War")]
#new3_1 = new3_1.loc[(new3_1.genres == "War")]
#new1_1 = new1_1.loc[(new1_1.genres == "Sci-Fi")]
#new2_1 = new2_1.loc[(new2_1.genres == "Sci-Fi")]
#new3_1 = new3_1.loc[(new3_1.genres == "Sci-Fi")]
new1_1 = new1_1.loc[(new1_1.genres == "Thriller")]
new2_1 = new2_1.loc[(new2_1.genres == "Thriller")]
new3_1 = new3_1.loc[(new3_1.genres == "Thriller")]

#ELIMINACION DE COLUMNA session_id 
new1_1.drop(new1_1.columns[4], axis=1, inplace=True)
new2_1.drop(new2_1.columns[4], axis=1, inplace=True)
new3_1.drop(new3_1.columns[4], axis=1, inplace=True)

#rESETEAMOS EL INDICE
new1_1.reset_index(inplace=True, drop=False)
new2_1.reset_index(inplace=True, drop=False)
new3_1.reset_index(inplace=True, drop=False)

#CARGAMOS EL NUEVO INDICE A LA COLUMNA SESSION_ID
new1_1['session_id'] = new1_1.index
new2_1['session_id'] = new2_1.index
new3_1['session_id'] = new3_1.index

#ELIMINACION DE COLUMNA INDEX 
new1_1.drop(new1_1.columns[0], axis=1, inplace=True)
new2_1.drop(new2_1.columns[0], axis=1, inplace=True)
new3_1.drop(new3_1.columns[0], axis=1, inplace=True)

#TRANSFORMACION DE DECIMAL A ENTERO
new1_1['RatingsGroups'] = new1_1['RatingsGroups']*100
new2_1['RatingsGroups'] = new2_1['RatingsGroups']*100
new3_1['RatingsGroups'] = new3_1['RatingsGroups']*100

#Elimino valores NAN
new1_1.dropna(subset = ["RatingsGroups"], inplace=True)
new2_1.dropna(subset = ["RatingsGroups"], inplace=True)
new3_1.dropna(subset = ["RatingsGroups"], inplace=True)

new1_1['RatingsGroups'] = new1_1['RatingsGroups'].astype(int,errors='ignore')
new2_1['RatingsGroups'] = new2_1['RatingsGroups'].astype(int,errors='ignore')
new3_1['RatingsGroups'] = new3_1['RatingsGroups'].astype(int,errors='ignore')

new1_1['mmovieId'] = new1_1['mmovieId'].astype(int,errors='ignore')
new2_1['mmovieId'] = new2_1['mmovieId'].astype(int,errors='ignore')
new3_1['mmovieId'] = new3_1['mmovieId'].astype(int,errors='ignore')
print(new1_1)
print(new2_1)
print(new3_1)
import os
if(os.path.exists('MPS1Size5_war0.csv')):
    os.remove("MPS1Size5_war0.csv")
if(os.path.exists('MPS1Size5_war.csv')):
    os.remove("MPS1Size5_war.csv")

import csv
with open('MPS1Size5_war0.csv', 'w', newline='') as file:
    writer = csv.writer(file)
file.close()
with open('MPS1Size5_war.csv', 'w', newline='') as file:
    writer = csv.writer(file)
file.close()

with open('MPS1Size5_war0.csv', 'a') as f:
    new1_1.to_csv(f,index=False)
    new2_1.to_csv(f,header=False,index=False)
    new3_1.to_csv(f,header=False,index=False)
f.close()

with open('MPS1Size5_war0.csv') as input, open('MPS1Size5_war.csv', 'w', newline='') as output:
     writer = csv.writer(output)
     for row in csv.reader(input):
         if any(field.strip() for field in row):
             writer.writerow(row)

df003 = pd.read_csv('MPS1Size5_war.csv')
print(df003)
# Out:
# C:\Users\ChrisLex\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# <ipython-input-16-ed3282eaf162>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1['session_id'] = new1_1.index
# <ipython-input-16-ed3282eaf162>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1['session_id'] = new2_1.index
# <ipython-input-16-ed3282eaf162>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1['session_id'] = new3_1.index
# <ipython-input-16-ed3282eaf162>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1['RatingsGroups'] = new1_1['RatingsGroups']*100
# <ipython-input-16-ed3282eaf162>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1['RatingsGroups'] = new2_1['RatingsGroups']*100
# <ipython-input-16-ed3282eaf162>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1['RatingsGroups'] = new3_1['RatingsGroups']*100
# <ipython-input-16-ed3282eaf162>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1.dropna(subset = ["RatingsGroups"], inplace=True)
# <ipython-input-16-ed3282eaf162>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1.dropna(subset = ["RatingsGroups"], inplace=True)
# <ipython-input-16-ed3282eaf162>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1.dropna(subset = ["RatingsGroups"], inplace=True)
# <ipython-input-16-ed3282eaf162>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1['RatingsGroups'] = new1_1['RatingsGroups'].astype(int)
# <ipython-input-16-ed3282eaf162>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1['RatingsGroups'] = new2_1['RatingsGroups'].astype(int)
# <ipython-input-16-ed3282eaf162>:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1['RatingsGroups'] = new3_1['RatingsGroups'].astype(int)
# <ipython-input-16-ed3282eaf162>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1['mmovieId'] = new1_1['mmovieId'].astype(int)
# <ipython-input-16-ed3282eaf162>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1['mmovieId'] = new2_1['mmovieId'].astype(int)
# <ipython-input-16-ed3282eaf162>:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1['mmovieId'] = new3_1['mmovieId'].astype(int)
#        GroupID  mmovieId  RatingsGroups            ts  session_id
# 0            0       132            366  1.650398e+09           0
# 1            1       132            401  1.650398e+09           1
# 2            2       132            373  1.650398e+09           2
# 3            3       132            368  1.650398e+09           3
# 4            4       132            357  1.650398e+09           4
# ...        ...       ...            ...           ...         ...
# 44545      805     71011            374  1.650398e+09       44545
# 44546      806     71011            365  1.650398e+09       44546
# 44547      807     71011            372  1.650398e+09       44547
# 44548      808     71011            362  1.650398e+09       44548
# 44549      809     71011            405  1.650398e+09       44549
#
# [44505 rows x 5 columns]
#        GroupID  mmovieId  RatingsGroups            ts  session_id
# 0            0       132            347  1.650398e+09           0
# 1            1       132            387  1.650398e+09           1
# 2            2       132            394  1.650398e+09           2
# 3            3       132            400  1.650398e+09           3
# 4            4       132            349  1.650398e+09           4
# ...        ...       ...            ...           ...         ...
# 44545      805     71011            375  1.650398e+09       44545
# 44546      806     71011            411  1.650398e+09       44546
# 44547      807     71011            376  1.650398e+09       44547
# 44548      808     71011            359  1.650398e+09       44548
# 44549      809     71011            369  1.650398e+09       44549
#
# [44505 rows x 5 columns]
#        GroupID  mmovieId  RatingsGroups            ts  session_id
# 0            0       132            338  1.650398e+09           0
# 1            1       132            336  1.650398e+09           1
# 2            2       132            377  1.650398e+09           2
# 3            3       132            377  1.650398e+09           3
# 4            4       132            328  1.650398e+09           4
# ...        ...       ...            ...           ...         ...
# 44545      805     71011            341  1.650398e+09       44545
# 44546      806     71011            347  1.650398e+09       44546
# 44547      807     71011            386  1.650398e+09       44547
# 44548      808     71011            368  1.650398e+09       44548
# 44549      809     71011            446  1.650398e+09       44549
#
# [44505 rows x 5 columns]
#         GroupID  mmovieId  RatingsGroups            ts  session_id
# 0             0       132            366  1.650398e+09           0
# 1             1       132            401  1.650398e+09           1
# 2             2       132            373  1.650398e+09           2
# 3             3       132            368  1.650398e+09           3
# 4             4       132            357  1.650398e+09           4
# ...         ...       ...            ...           ...         ...
# 133510      805     71011            341  1.650398e+09       44545
# 133511      806     71011            347  1.650398e+09       44546
# 133512      807     71011            386  1.650398e+09       44547
# 133513      808     71011            368  1.650398e+09       44548
# 133514      809     71011            446  1.650398e+09       44549
#
# [133515 rows x 5 columns]

# %%
#SIZE 8

# %%
new1 = pd.merge(size8_MPS1, UniqueGenre, on='mmovieId', how='left')
new1.drop(new1.columns[5], axis=1, inplace=True)
new1.drop(new1.columns[3], axis=1, inplace=True)

new2 = pd.merge(size8_MPS2, UniqueGenre, on='mmovieId', how='left')
new2.drop(new2.columns[5], axis=1, inplace=True)
new2.drop(new2.columns[3], axis=1, inplace=True)

new3 = pd.merge(size8_MPS3, UniqueGenre, on='mmovieId', how='left')
new3.drop(new3.columns[5], axis=1, inplace=True)
new3.drop(new3.columns[3], axis=1, inplace=True)

# %%
#GENERO War
new1_1 = new1
new2_1 = new2
new3_1 = new3

#FILTRO DE GENERO Sci-Fi
#new1_1 = new1_1.loc[(new1_1.genres == "War")]
#new2_1 = new2_1.loc[(new2_1.genres == "War")]
#new3_1 = new3_1.loc[(new3_1.genres == "War")]
#new1_1 = new1_1.loc[(new1_1.genres == "Sci-Fi")]
#new2_1 = new2_1.loc[(new2_1.genres == "Sci-Fi")]
#new3_1 = new3_1.loc[(new3_1.genres == "Sci-Fi")]
new1_1 = new1_1.loc[(new1_1.genres == "Thriller")]
new2_1 = new2_1.loc[(new2_1.genres == "Thriller")]
new3_1 = new3_1.loc[(new3_1.genres == "Thriller")]

#ELIMINACION DE COLUMNA session_id 
new1_1.drop(new1_1.columns[4], axis=1, inplace=True)
new2_1.drop(new2_1.columns[4], axis=1, inplace=True)
new3_1.drop(new3_1.columns[4], axis=1, inplace=True)

#rESETEAMOS EL INDICE
new1_1.reset_index(inplace=True, drop=False)
new2_1.reset_index(inplace=True, drop=False)
new3_1.reset_index(inplace=True, drop=False)

#CARGAMOS EL NUEVO INDICE A LA COLUMNA SESSION_ID
new1_1['session_id'] = new1_1.index
new2_1['session_id'] = new2_1.index
new3_1['session_id'] = new3_1.index

#ELIMINACION DE COLUMNA INDEX 
new1_1.drop(new1_1.columns[0], axis=1, inplace=True)
new2_1.drop(new2_1.columns[0], axis=1, inplace=True)
new3_1.drop(new3_1.columns[0], axis=1, inplace=True)

#TRANSFORMACION DE DECIMAL A ENTERO
new1_1['RatingsGroups'] = new1_1['RatingsGroups']*100
new2_1['RatingsGroups'] = new2_1['RatingsGroups']*100
new3_1['RatingsGroups'] = new3_1['RatingsGroups']*100

#Elimino valores NAN
new1_1.dropna(subset = ["RatingsGroups"], inplace=True)
new2_1.dropna(subset = ["RatingsGroups"], inplace=True)
new3_1.dropna(subset = ["RatingsGroups"], inplace=True)

new1_1['RatingsGroups'] = new1_1['RatingsGroups'].astype(int,errors='ignore')
new2_1['RatingsGroups'] = new2_1['RatingsGroups'].astype(int,errors='ignore')
new3_1['RatingsGroups'] = new3_1['RatingsGroups'].astype(int,errors='ignore')

new1_1['mmovieId'] = new1_1['mmovieId'].astype(int,errors='ignore')
new2_1['mmovieId'] = new2_1['mmovieId'].astype(int,errors='ignore')
new3_1['mmovieId'] = new3_1['mmovieId'].astype(int,errors='ignore')

import os
if(os.path.exists('MPS1Size8_war0.csv')):
    os.remove("MPS1Size8_war0.csv")
if(os.path.exists('MPS1Size8_war.csv')):
    os.remove("MPS1Size8_war.csv")

import csv
with open('MPS1Size8_war0.csv', 'w', newline='') as file:
    writer = csv.writer(file)
file.close()
with open('MPS1Size8_war.csv', 'w', newline='') as file:
    writer = csv.writer(file)
file.close()

with open('MPS1Size8_war0.csv', 'a') as f:
    new1_1.to_csv(f,index=False)
    new2_1.to_csv(f,header=False,index=False)
    new3_1.to_csv(f,header=False,index=False)
f.close()

with open('MPS1Size8_war0.csv') as input, open('MPS1Size8_war.csv', 'w', newline='') as output:
     writer = csv.writer(output)
     for row in csv.reader(input):
         if any(field.strip() for field in row):
             writer.writerow(row)

df003 = pd.read_csv('MPS1Size8_war.csv')
print(df003)
# Out:
# C:\Users\ChrisLex\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# <ipython-input-19-ceeaa469c8ed>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1['session_id'] = new1_1.index
# <ipython-input-19-ceeaa469c8ed>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1['session_id'] = new2_1.index
# <ipython-input-19-ceeaa469c8ed>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1['session_id'] = new3_1.index
# <ipython-input-19-ceeaa469c8ed>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1['RatingsGroups'] = new1_1['RatingsGroups']*100
# <ipython-input-19-ceeaa469c8ed>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1['RatingsGroups'] = new2_1['RatingsGroups']*100
# <ipython-input-19-ceeaa469c8ed>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1['RatingsGroups'] = new3_1['RatingsGroups']*100
# <ipython-input-19-ceeaa469c8ed>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1.dropna(subset = ["RatingsGroups"], inplace=True)
# <ipython-input-19-ceeaa469c8ed>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1.dropna(subset = ["RatingsGroups"], inplace=True)
# <ipython-input-19-ceeaa469c8ed>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1.dropna(subset = ["RatingsGroups"], inplace=True)
# <ipython-input-19-ceeaa469c8ed>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1['RatingsGroups'] = new1_1['RatingsGroups'].astype(int)
# <ipython-input-19-ceeaa469c8ed>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1['RatingsGroups'] = new2_1['RatingsGroups'].astype(int)
# <ipython-input-19-ceeaa469c8ed>:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1['RatingsGroups'] = new3_1['RatingsGroups'].astype(int)
# <ipython-input-19-ceeaa469c8ed>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1['mmovieId'] = new1_1['mmovieId'].astype(int)
# <ipython-input-19-ceeaa469c8ed>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1['mmovieId'] = new2_1['mmovieId'].astype(int)
# <ipython-input-19-ceeaa469c8ed>:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1['mmovieId'] = new3_1['mmovieId'].astype(int)
#         GroupID  mmovieId  RatingsGroups            ts  session_id
# 0             0       132            370  1.650398e+09           0
# 1             1       132            382  1.650398e+09           1
# 2             2       132            404  1.650398e+09           2
# 3             3       132            384  1.650398e+09           3
# 4             4       132            359  1.650398e+09           4
# ...         ...       ...            ...           ...         ...
# 131809      794     71011            361  1.650398e+09       43940
# 131810      795     71011            383  1.650398e+09       43941
# 131811      796     71011            371  1.650398e+09       43942
# 131812      797     71011            349  1.650398e+09       43943
# 131813      798     71011            346  1.650398e+09       43944
#
# [131814 rows x 5 columns]

# %%
#GENERO Sci-Fi
new1_1 = new1
new2_1 = new2
new3_1 = new3

#FILTRO DE GENERO Sci-Fi
new1_1 = new1_1.loc[(new1_1.genres == "Sci-Fi")]
new2_1 = new2_1.loc[(new2_1.genres == "Sci-Fi")]
new3_1 = new3_1.loc[(new3_1.genres == "Sci-Fi")]

#ELIMINACION DE COLUMNA session_id 
new1_1.drop(new1_1.columns[4], axis=1, inplace=True)
new2_1.drop(new2_1.columns[4], axis=1, inplace=True)
new3_1.drop(new3_1.columns[4], axis=1, inplace=True)

#rESETEAMOS EL INDICE
new1_1.reset_index(inplace=True, drop=False)
new2_1.reset_index(inplace=True, drop=False)
new3_1.reset_index(inplace=True, drop=False)

#CARGAMOS EL NUEVO INDICE A LA COLUMNA SESSION_ID
new1_1['session_id'] = new1_1.index
new2_1['session_id'] = new2_1.index
new3_1['session_id'] = new3_1.index

#ELIMINACION DE COLUMNA INDEX 
new1_1.drop(new1_1.columns[0], axis=1, inplace=True)
new2_1.drop(new2_1.columns[0], axis=1, inplace=True)
new3_1.drop(new3_1.columns[0], axis=1, inplace=True)

#TRANSFORMACION DE DECIMAL A ENTERO
new1_1['RatingsGroups'] = new1_1['RatingsGroups']*100
new2_1['RatingsGroups'] = new2_1['RatingsGroups']*100
new3_1['RatingsGroups'] = new3_1['RatingsGroups']*100

#Elimino valores NAN
new1_1.dropna(subset = ["RatingsGroups"], inplace=True)
new2_1.dropna(subset = ["RatingsGroups"], inplace=True)
new3_1.dropna(subset = ["RatingsGroups"], inplace=True)

new1_1['RatingsGroups'] = new1_1['RatingsGroups'].astype(int,errors='ignore')
new2_1['RatingsGroups'] = new2_1['RatingsGroups'].astype(int,errors='ignore')
new3_1['RatingsGroups'] = new3_1['RatingsGroups'].astype(int,errors='ignore')

new1_1['mmovieId'] = new1_1['mmovieId'].astype(int,errors='ignore')
new2_1['mmovieId'] = new2_1['mmovieId'].astype(int,errors='ignore')
new3_1['mmovieId'] = new3_1['mmovieId'].astype(int,errors='ignore')

import os

if(os.path.exists('MPS1Size8_sf0.csv')):
    os.remove("MPS1Size8_sf0.csv")
if(os.path.exists('MPS1Size8_sf.csv')):
    os.remove("MPS1Size8_sf.csv")

import csv
with open('MPS1Size8_sf0.csv', 'w', newline='') as file:
    writer = csv.writer(file)
file.close()
with open('MPS1Size8_sf.csv', 'w', newline='') as file:
    writer = csv.writer(file)
file.close()

with open('MPS1Size8_sf0.csv', 'a') as f:
    new1_1.to_csv(f,index=False)
    new2_1.to_csv(f,header=False,index=False)
    new3_1.to_csv(f,header=False,index=False)
f.close()

with open('MPS1Size8_sf0.csv') as input, open('MPS1Size8_sf.csv', 'w', newline='') as output:
     writer = csv.writer(output)
     for row in csv.reader(input):
         if any(field.strip() for field in row):
             writer.writerow(row)

df003 = pd.read_csv('MPS1Size8_sf.csv')
print(df003)
# Out:
# C:\Users\ChrisLex\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# <ipython-input-20-0f546c1ccbe8>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1['session_id'] = new1_1.index
# <ipython-input-20-0f546c1ccbe8>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1['session_id'] = new2_1.index
# <ipython-input-20-0f546c1ccbe8>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1['session_id'] = new3_1.index
# <ipython-input-20-0f546c1ccbe8>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1['RatingsGroups'] = new1_1['RatingsGroups']*100
# <ipython-input-20-0f546c1ccbe8>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1['RatingsGroups'] = new2_1['RatingsGroups']*100
# <ipython-input-20-0f546c1ccbe8>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1['RatingsGroups'] = new3_1['RatingsGroups']*100
# <ipython-input-20-0f546c1ccbe8>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1.dropna(subset = ["RatingsGroups"], inplace=True)
# <ipython-input-20-0f546c1ccbe8>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1.dropna(subset = ["RatingsGroups"], inplace=True)
# <ipython-input-20-0f546c1ccbe8>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1.dropna(subset = ["RatingsGroups"], inplace=True)
# <ipython-input-20-0f546c1ccbe8>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1['RatingsGroups'] = new1_1['RatingsGroups'].astype(int)
# <ipython-input-20-0f546c1ccbe8>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1['RatingsGroups'] = new2_1['RatingsGroups'].astype(int)
# <ipython-input-20-0f546c1ccbe8>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1['RatingsGroups'] = new3_1['RatingsGroups'].astype(int)
# <ipython-input-20-0f546c1ccbe8>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new1_1['mmovieId'] = new1_1['mmovieId'].astype(int)
# <ipython-input-20-0f546c1ccbe8>:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2_1['mmovieId'] = new2_1['mmovieId'].astype(int)
# <ipython-input-20-0f546c1ccbe8>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new3_1['mmovieId'] = new3_1['mmovieId'].astype(int)
#        GroupID  mmovieId  RatingsGroups            ts  session_id
# 0            0       880            303  1.650398e+09           0
# 1            1       880            315  1.650398e+09           1
# 2            2       880            341  1.650398e+09           2
# 3            3       880            307  1.650398e+09           3
# 4            4       880            277  1.650398e+09           4
# ...        ...       ...            ...           ...         ...
# 57523      794     72630            358  1.650398e+09       19171
# 57524      795     72630            376  1.650398e+09       19172
# 57525      796     72630            360  1.650398e+09       19173
# 57526      797     72630            362  1.650398e+09       19174
# 57527      798     72630            368  1.650398e+09       19175
#
# [57528 rows x 5 columns]
